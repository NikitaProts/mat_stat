# %%
import numpy as np
from scipy import stats
from scipy.stats import f_oneway

# %% [markdown]
# ### Задание 1
# Провести дисперсионный анализ для определения того, есть ли различия среднего роста среди взрослых футболистов, хоккеистов и штангистов. Даны значения роста в трех группах случайно выбранных спортсменов:
#
# football_players = [173, 175, 180, 178, 177, 185, 183, 182]
# hockey_players = [177, 179, 180, 188, 177, 172, 171, 184, 180]
# lifters = [172, 173, 169, 177, 166, 180, 178, 177, 172, 166, 170]

# %%
football_players = np.array([173, 175, 180, 178, 177, 185, 183, 182])
hockey_players = np.array([177, 179, 180, 188, 177, 172, 171, 184, 180])
lifters = np.array([172, 173, 169, 177, 166, 180, 178, 177, 172, 166, 170])

# %%
#Размерность
n_football = football_players.shape[0]
n_hockey = hockey_players.shape[0]
n_lifters = lifters.shape[0]

# %%
#Среднее по каждой группе
y_mean_football = football_players.mean()
y_mean_hockey = hockey_players.mean()
y_mean_lifters = lifters.mean()

y_mean_football, y_mean_hockey, y_mean_lifters
# Out:
# (179.125, 178.66666666666666, 172.72727272727272)

# %% [markdown]
# Среди данных групп спортсменов видна небольшая разница в росте

# %%
# Все даныне в один массив
y = np.concatenate([football_players, hockey_players, lifters])
print(y)
# Out:
# [173 175 180 178 177 185 183 182 177 179 180 188 177 172 171 184 180 172
#  173 169 177 166 180 178 177 172 166 170]

# %%
y_mean = y.mean()
y_mean
# Out:
# 176.46428571428572

# %% [markdown]
# Найдём значения $S_b$ и $S_{w}$:

# %%
S2_b = n_football * (y_mean_football - y_mean) ** 2 + n_hockey * (y_mean_hockey - y_mean) ** 2 + n_lifters * (y_mean_lifters - y_mean) ** 2

S2_w = ((football_players - y_mean_football) ** 2).sum() + ((hockey_players - y_mean_hockey) ** 2).sum() + ((lifters - y_mean_lifters) ** 2).sum()

S2_b, S2_w
# Out:
# (253.9074675324678, 577.0568181818182)

# %%
((y - y_mean) ** 2).sum()
# Out:
# 830.9642857142854

# %%
S2_b + S2_w
# Out:
# 830.964285714286

# %% [markdown]
# Оценки дисперсией

# %%
k = 3
n = n_football + n_hockey + n_lifters

k1 = k - 1
k2 = n - k

sigma2_b = S2_b / k1
sigma2_w = S2_w / k2

sigma2_b, sigma2_w
# Out:
# (126.9537337662339, 23.08227272727273)

# %%
# T статистика

T = sigma2_b / sigma2_w
T
# Out:
# 5.500053450812598

# %%
alpha = 0.05 # уровень значимости

F_crit = stats.f.ppf(1 - alpha, k1, k2)
F_crit
# Out:
# 3.3851899614491687

# %%
p = 1 - stats.f.cdf(T, k1, k2)
p
# Out:
# 0.010482206918698611

# %% [markdown]
# Видим, что $T > F_{crit}$, поэтому заключаем, что отличие средних зарплат действительно является статистически значимым.

# %%
f_oneway(football_players, hockey_players, lifters)
# Out:
# F_onewayResult(statistic=5.500053450812596, pvalue=0.010482206918698694)
